# %%
#Exercise 1 
#intializing neuron membrane
V_membrane = float (-75) # Using a float to represent the membrane potential
V_membrane = V_membrane + 1 # Adding 1 mV to the current membrane potential
print (V_membrane)
# Out:
# -74.0

# %%
#Exercise 2 
#Initialize the Variable with Value 1
variable = 1
print(type(variable))  # Check the type of the variable
variable *= 0.7
print(type(variable))  # Check the type of the variable
variable = 1.0
print(type(variable))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'float'>

# %% [markdown]
# ![Screenshot 2023-09-15 at 16.56.20.png](attachment:28f62104-2448-4f96-a6db-cc5224e036f1.png)

# %%
import sys 
membrane_potential = -75
spike = sys.argv[1]


membrane_potential += float(spike)


if membrane_potential >= -65.0:
    print("5.0")  
else:
    print("0")

# %%
membrane_potential = -75  


input_spike = float(input())


membrane_potential = membrane_potential + input_spike
print("input_spike=",input_spike)

if membrane_potential >= -65.0:
    
    print("5.0")  
else:
    print("0")
